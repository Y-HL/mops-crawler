# %%
import requests
import pandas as pd
from bs4 import BeautifulSoup
import os

if not os.path.isdir('./MOPS_balance_sheet'):
    os.mkdir('./MOPS_balance_sheet')
headers = {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/81.0.4044.138 Safari/537.36'}
data = {
    'encodeURIComponent': 1,
    'step': 1,
    'firstin': 1,
    'off': 1,
    'queryName':'co_id',
    'inpuType':'co_id',
    'TYPEK':'all',
    'isnew':'false',
    'co_id':2330,
    'year':107,
    'season':'01'
}

resp = requests.post('https://mops.twse.com.tw/mops/web/ajax_t164sb03', data=data, headers=headers, timeout=2)
soup = BeautifulSoup(resp.text, 'lxml')
content = soup.find_all('table')[1].find_all('td')

data=[]
row=[]
for i in range(len(content)):
    if i%7>0:
        row.append(content[i].text.replace('\u3000',"").replace(' ','').replace('　',''))
    else:
        print(row)
        data.append(row)
        row=[]
        row.append(content[i].text.replace('\u3000',"").replace(' ','').replace('　',''))
        

df = pd.DataFrame(data=data)
df.to_csv('./MOPS_balance_sheet/{}.csv'.format('10701'), index=0, encoding='utf-8-sig')
# Out:
# []
# ['流動資產', '', '', '', '', '', '']
# ['現金及約當現金', '577,782,963', '28.20', '553,391,696', '27.78', '564,725,266', '29.19']
# ['透過損益按公允價值衡量之金融資產－流動', '963,915', '0.05', '569,751', '0.03', '5,374,003', '0.28']
# ['透過其他綜合損益按公允價值衡量之金融資產－流動', '95,713,446', '4.67', '0', '0.00', '0', '0.00']
# ['備供出售金融資產－流動淨額', '0', '0.00', '93,374,153', '4.69', '71,083,797', '3.67']
# ['持有至到期日金融資產－流動淨額', '0', '0.00', '1,988,385', '0.10', '18,140,374', '0.94']
# ['避險之衍生金融資產－流動', '0', '0.00', '34,394', '0.00', '0', '0.00']
# ['按攤銷後成本衡量之金融資產－流動淨額', '9,888,741', '0.48', '0', '0.00', '0', '0.00']
# ['避險之金融資產－流動', '26,357', '0.00', '0', '0.00', '0', '0.00']
# ['應收帳款淨額', '106,601,372', '5.20', '121,133,248', '6.08', '108,532,829', '5.61']
# ['應收帳款－關係人淨額', '1,179,312', '0.06', '1,184,124', '0.06', '494,839', '0.03']
# ['其他應收款－關係人淨額', '130,070', '0.01', '171,058', '0.01', '135,051', '0.01']
# ['存貨', '85,215,899', '4.16', '73,880,747', '3.71', '50,389,022', '2.60']
# ['其他流動資產', '51,614,585', '2.52', '11,475,554', '0.58', '6,786,652', '0.35']
# ['流動資產合計', '929,116,660', '45.34', '857,203,110', '43.04', '825,661,833', '42.68']
# ['非流動資產', '', '', '', '', '', '']
# ['透過其他綜合損益按公允價值衡量之金融資產－非流動', '6,035,904', '0.29', '0', '0.00', '0', '0.00']
# ['持有至到期日金融資產－非流動淨額', '0', '0.00', '18,833,329', '0.95', '20,499,458', '1.06']
# ['按攤銷後成本衡量之金融資產－非流動淨額', '10,033,241', '0.49', '0', '0.00', '0', '0.00']
# ['以成本衡量之金融資產－非流動淨額', '0', '0.00', '4,874,257', '0.24', '4,079,292', '0.21']
# ['採用權益法之投資淨額', '18,307,517', '0.89', '17,861,488', '0.90', '19,940,062', '1.03']
# ['不動產、廠房及設備', '1,055,366,207', '51.50', '1,062,542,322', '53.34', '1,037,364,143', '53.62']
# ['無形資產', '13,674,295', '0.67', '14,175,140', '0.71', '14,278,436', '0.74']
# ['遞延所得稅資產', '12,987,042', '0.63', '12,105,463', '0.61', '10,644,401', '0.55']
# ['其他非流動資產', '3,634,940', '0.18', '4,266,534', '0.21', '2,196,136', '0.11']
# ['非流動資產合計', '1,120,039,146', '54.66', '1,134,658,533', '56.96', '1,109,001,928', '57.32']
# ['資產總額', '2,049,155,806', '100.00', '1,991,861,643', '100.00', '1,934,663,761', '100.00']
# ['流動負債', '', '', '', '', '', '']
# ['短期借款', '56,731,350', '2.77', '63,766,850', '3.20', '54,666,000', '2.83']
# ['透過損益按公允價值衡量之金融負債－流動', '170,673', '0.01', '26,709', '0.00', '124,935', '0.01']
# ['避險之衍生金融負債－流動', '0', '0.00', '15,562', '0.00', '3,908', '0.00']
# ['避險之金融負債－流動', '79,182', '0.00', '0', '0.00', '0', '0.00']
# ['應付帳款', '27,817,670', '1.36', '28,412,807', '1.43', '23,081,567', '1.19']
# ['應付帳款－關係人', '1,224,307', '0.06', '1,656,356', '0.08', '1,171,195', '0.06']
# ['其他應付款', '87,558,623', '4.27', '93,397,780', '4.69', '97,233,234', '5.03']
# ['本期所得稅負債', '44,096,800', '2.15', '33,479,311', '1.68', '52,874,433', '2.73']
# ['負債準備－流動', '0', '0.00', '13,961,787', '0.70', '11,298,320', '0.58']
# ['其他流動負債', '124,556,637', '6.08', '123,989,518', '6.22', '81,126,932', '4.19']
# ['流動負債合計', '342,235,242', '16.70', '358,706,680', '18.01', '321,580,524', '16.62']
# ['非流動負債', '', '', '', '', '', '']
# ['應付公司債', '83,400,000', '4.07', '91,800,000', '4.61', '134,198,769', '6.94']
# ['長期借款', '0', '0.00', '0', '0.00', '19,360', '0.00']
# ['遞延所得稅負債', '285,644', '0.01', '302,205', '0.02', '90,944', '0.00']
# ['其他非流動負債', '16,629,891', '0.81', '18,293,115', '0.92', '22,464,139', '1.16']
# ['非流動負債合計', '100,315,535', '4.90', '110,395,320', '5.54', '156,773,212', '8.10']
# ['負債總額', '442,550,777', '21.60', '469,102,000', '23.55', '478,353,736', '24.73']
# ['歸屬於母公司業主之權益', '', '', '', '', '', '']
# ['股本', '', '', '', '', '', '']
# ['普通股股本', '259,303,805', '12.65', '259,303,805', '13.02', '259,303,805', '13.40']
# ['股本合計', '259,303,805', '12.65', '259,303,805', '13.02', '259,303,805', '13.40']
# ['資本公積', '', '', '', '', '', '']
# ['資本公積－發行溢價', '33,077,786', '1.61', '33,077,786', '1.66', '33,077,786', '1.71']
# ['資本公積-認列對子公司所有權權益變動數', '118,792', '0.01', '118,792', '0.01', '107,798', '0.01']
# ['資本公積－受贈資產', '19,248', '0.00', '19,208', '0.00', '55', '0.00']
# ['資本公積－採用權益法認列關聯企業及合資股權淨值之變動數', '285,415', '0.01', '289,240', '0.01', '291,969', '0.02']
# ['資本公積－合併溢額', '22,804,510', '1.11', '22,804,510', '1.14', '22,804,510', '1.18']
# ['資本公積合計', '56,305,751', '2.75', '56,309,536', '2.83', '56,282,118', '2.91']
# ['保留盈餘', '', '', '', '', '', '']
# ['法定盈餘公積', '241,722,663', '11.80', '241,722,663', '12.14', '208,297,945', '10.77']
# ['未分配盈餘（或待彌補虧損）', '1,082,967,237', '52.85', '991,639,347', '49.78', '951,339,122', '49.17']
# ['保留盈餘合計', '1,324,689,900', '64.65', '1,233,362,010', '61.92', '1,159,637,067', '59.94']
# ['其他權益', '', '', '', '', '', '']
# ['其他權益合計', '-34,401,067', '-1.68', '-26,917,818', '-1.35', '-19,709,627', '-1.02']
# ['歸屬於母公司業主之權益合計', '1,605,898,389', '78.37', '1,522,057,533', '76.41', '1,455,513,363', '75.23']
# ['非控制權益', '706,640', '0.03', '702,110', '0.04', '796,662', '0.04']
# ['權益總額', '1,606,605,029', '78.40', '1,522,759,643', '76.45', '1,456,310,025', '75.27']
# ['負債及權益總計', '2,049,155,806', '100.00', '1,991,861,643', '100.00', '1,934,663,761', '100.00']
# ['預收股款（權益項下）之約當發行股數（單位：股）', '0', '', '0', '', '0', '']

# %%
data=[]
row=[]
for i in range(len(content)):
    if i%5>0:
        row.append(content[i].text.replace('\u3000',"").replace(' ','').replace('　',''))
    else:
        print(row)
        data.append(row)
        row=[]
        row.append(content[i].text.replace('\u3000',"").replace(' ','').replace('　',''))
        

df = pd.DataFrame(data=data)
df.to_csv('./mops_fs/{}.csv'.format('10701'), index=0, encoding='utf-8-sig')
