# %%
import requests
import pandas as pd
from bs4 import BeautifulSoup
import os

if not os.path.isdir('./MOPS_statement_of_comprehensive_income'):
    os.mkdir('./MOPS_statement_of_comprehensive_income')
headers = {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/81.0.4044.138 Safari/537.36'}
data = {
    'encodeURIComponent': 1,
    'step': 1,
    'firstin': 1,
    'off': 1,
    'queryName':'co_id',
    'inpuType':'co_id',
    'TYPEK':'all',
    'isnew':'false',
    'co_id':2330,
    'year':107,
    'season':'01'
}

resp = requests.post('https://mops.twse.com.tw/mops/web/ajax_t164sb04', data=data, headers=headers, timeout=2)
soup = BeautifulSoup(resp.text, 'lxml')
content = soup.find_all('table')[1].find_all('td')

data=[]
row=[]
for i in range(len(content)):
    if i%5>0:
        row.append(content[i].text.replace('\u3000',"").replace(' ','').replace('　',''))
    else:
        print(row)
        data.append(row)
        row=[]
        row.append(content[i].text.replace('\u3000',"").replace(' ','').replace('　',''))
        

df = pd.DataFrame(data=data)
df.to_csv('./MOPS_statement_of_comprehensive_income/{}.csv'.format('10701'), index=0, encoding='utf-8-sig')
# Out:
# []
# ['營業收入合計', '248,078,671', '100.00', '233,914,400', '100.00']
# ['營業成本合計', '123,103,977', '49.62', '112,428,734', '48.06']
# ['營業毛利（毛損）', '124,974,694', '50.38', '121,485,666', '51.94']
# ['已實現銷貨（損）益', '-117,155', '-0.05', '3,970', '0.00']
# ['營業毛利（毛損）淨額', '124,857,539', '50.33', '121,489,636', '51.94']
# ['營業費用', '', '', '', '']
# ['推銷費用', '1,448,092', '0.58', '1,496,487', '0.64']
# ['管理費用', '4,851,708', '1.96', '5,247,603', '2.24']
# ['研究發展費用', '20,428,594', '8.23', '19,412,393', '8.30']
# ['營業費用合計', '26,728,394', '10.77', '26,156,483', '11.18']
# ['其他收益及費損淨額', '', '', '', '']
# ['其他收益及費損淨額', '-1,302,199', '-0.52', '19,237', '0.01']
# ['營業利益（損失）', '96,826,946', '39.03', '95,352,390', '40.76']
# ['營業外收入及支出', '', '', '', '']
# ['其他收入', '3,154,642', '1.27', '2,104,979', '0.90']
# ['其他利益及損失淨額', '88,208', '0.04', '514,984', '0.22']
# ['財務成本淨額', '807,966', '0.33', '816,664', '0.35']
# ['採用權益法認列之關聯企業及合資損益之份額淨額', '681,791', '0.27', '666,810', '0.29']
# ['營業外收入及支出合計', '3,116,675', '1.26', '2,470,109', '1.06']
# ['稅前淨利（淨損）', '99,943,621', '40.29', '97,822,499', '41.82']
# ['所得稅費用（利益）合計', '10,156,047', '4.09', '10,201,591', '4.36']
# ['繼續營業單位本期淨利（淨損）', '89,787,574', '36.19', '87,620,908', '37.46']
# ['本期淨利（淨損）', '89,787,574', '36.19', '87,620,908', '37.46']
# ['其他綜合損益(淨額)', '', '', '', '']
# ['不重分類至損益之項目：', '', '', '', '']
# ['透過其他綜合損益按公允價值衡量之權益工具投資未實現評價損益', '-19,507', '-0.01', '0', '0.00']
# ['避險工具之損益', '37,282', '0.02', '0', '0.00']
# ['採用權益法認列之關聯企業及合資之其他綜合損益之份額-不重分類至損益之項目', '62', '0.00', '0', '0.00']
# ['與不重分類之項目相關之所得稅', '-39,206', '-0.02', '0', '0.00']
# ['後續可能重分類至損益之項目：', '', '', '', '']
# ['國外營運機構財務報表換算之兌換差額', '-6,476,486', '-2.61', '-21,243,594', '-9.08']
# ['備供出售金融資產未實現評價損益', '0', '0.00', '-93,470', '-0.04']
# ['透過其他綜合損益按公允價值衡量之債務工具投資未實現評價損益', '-727,410', '-0.29', '0', '0.00']
# ['採用權益法認列關聯企業及合資之其他綜合損益之份額-可能重分類至損益之項目', '-39,352', '-0.02', '-61,657', '-0.03']
# ['與可能重分類之項目相關之所得稅', '0', '0.00', '-46,400', '-0.02']
# ['其他綜合損益（淨額）', '-7,186,205', '-2.90', '-21,352,321', '-9.13']
# ['本期綜合損益總額', '82,601,369', '33.30', '66,268,587', '28.33']
# ['淨利（損）歸屬於：', '', '', '', '']
# ['母公司業主（淨利／損）', '89,784,622', '36.19', '87,628,898', '37.46']
# ['非控制權益（淨利／損）', '2,952', '0.00', '-7,990', '0.00']
# ['母公司業主（綜合損益）', '82,596,052', '33.29', '66,274,790', '28.33']
# ['非控制權益（綜合損益）', '5,317', '0.00', '-6,203', '0.00']
# ['基本每股盈餘', '', '', '', '']
# ['基本每股盈餘', '3.46', '', '3.38', '']
# ['稀釋每股盈餘', '', '', '', '']
